# %% [markdown]
# # Task 3

# %% [markdown]
# ## Bandana Kar

# %% [markdown]
# ## Perform Explanatory Data Analysis on dataset 'Sample Superstore'

# %% [markdown]
# ### In this task we want to find out the weak areas where we can work for more profit.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing the dataset using pandas and print 5 rows from dataset

# %%
df = pd.read_csv(r'C:\Users\pc\Downloads\SampleSuperstore.csv')

df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ## Printing the last 5 rows

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %% [markdown]
# ## Finding any 5 rows from dataset

# %%
df.sample(5)
# Out:
#            Ship Mode      Segment        Country         City       State  \
# 9891    Second Class    Corporate  United States    Milwaukee   Wisconsin
# 898     Second Class    Corporate  United States       Auburn    New York
# 8497    Second Class     Consumer  United States      Yonkers    New York
# 6547  Standard Class  Home Office  United States     Elmhurst    Illinois
# 128     Second Class  Home Office  United States  Los Angeles  California
#
#       Postal Code   Region         Category Sub-Category    Sales  Quantity  \
# 9891        53209  Central       Technology  Accessories  124.250         7
# 898         13021     East  Office Supplies        Paper   46.960         8
# 8497        10701     East       Technology  Accessories  479.970         3
# 6547        60126  Central        Furniture       Chairs  634.116         6
# 128         90004     West        Furniture       Chairs   81.424         2
#
#       Discount    Profit
# 9891       0.0   48.4575
# 898        0.0   22.5408
# 8497       0.0  177.5889
# 6547       0.3 -172.1172
# 128        0.2   -9.1602

# %% [markdown]
# ## Describing the shape of data

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# ## Columns in the dataset

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ## Number of unique values in each column

# %%
for i in df.columns:
    print(i,len(df[i].unique()))
# Out:
# Ship Mode 4
# Segment 3
# Country 1
# City 531
# State 49
# Postal Code 631
# Region 4
# Category 3
# Sub-Category 17
# Sales 5825
# Quantity 14
# Discount 12
# Profit 7287

# %% [markdown]
# ## Check for null values

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ## Total information  about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ## Describing the statistical overview of the data

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ## Check for duplicate values

# %%
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ## Drop the duplicate values

# %%
df.drop_duplicates()
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ## Remove the columns that are not necessary

# %%
dataset = df.drop(['Postal Code'], axis=1)
dataset.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ## Visualising the whole dataset using pair plot

# %%
sns.pairplot(dataset,hue="Category")

# %%
sns.pairplot(dataset,hue="Region")

# %% [markdown]
# ## Correlation between the columns

# %%
dataset.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ## Find the pairwise correlation between the columns and visualising using heatmap

# %%
plt.figure(figsize=(8,4))
sns.heatmap(dataset.corr(), annot=True)
plt.show()

# %% [markdown]
# # From the above heatmap we have
# ## 1) Discount and Profit is negative correlated.
# ## 2) Quantity and Profit are less Moderately correlated.
# ## 3) Sales and Profit are Moderately correlated.

# %% [markdown]
# ## Count plot of category wise Analysis

# %%
plt.figure(figsize = (4,4))
plt.title('Category')
plt.pie(dataset['Category'].value_counts(), labels=dataset['Category'].value_counts().index,autopct='%.2f%%')
plt.show()

# %% [markdown]
# ## Count plot of region wise distribution

# %%
plt.figure(figsize = (4,4))
plt.title('Region')
plt.pie(dataset['Region'].value_counts(), labels=dataset['Region'].value_counts().index,autopct='%.2f%%')
plt.show()

# %% [markdown]
# ## Count plot of customer segments

# %%
plt.figure(figsize = (4,4))
plt.title('Segments')
plt.pie(dataset['Segment'].value_counts(), labels=dataset['Segment'].value_counts().index,autopct='%.2f%%')
plt.show()

# %% [markdown]
# ## Count plot of ship mode of distribution

# %%
plt.figure(figsize = (4,4))
plt.title('Ship Mode')
plt.pie(dataset['Ship Mode'].value_counts(), labels=dataset['Ship Mode'].value_counts().index,autopct='%.2f%%')
plt.show()

# %% [markdown]
# ## Segment-wise analysis of Profit, Sales and Discount

# %%
dataset.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %% [markdown]
# ## Quantity-wise analysis of Profit, Sales and Discount

# %%
dataset.groupby(['Quantity'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                 Sales  Discount      Profit
# Quantity
# 1           59.234632  0.152959    8.276396
# 2          120.354488  0.154858   16.006831
# 3          175.201578  0.153329   23.667715
# 4          271.764059  0.157708   37.131310
# 5          337.936339  0.157146   40.257394
# 6          362.101960  0.166556   18.051517
# 7          395.888393  0.161980   56.579163
# 8          458.210802  0.171595   42.244342
# 9          498.083683  0.147946   68.557716
# 10         422.046737  0.190702   35.862404
# 11         463.896529  0.097059  126.275503
# 12         646.452522  0.113043   51.524609
# 13        1197.710704  0.157407  235.144481
# 14         452.826138  0.151724   93.931166

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.countplot(x=dataset['Quantity'], hue=dataset['Region'])
plt.title('Region-wise ordered Quantity')
# Out:
# Text(0.5, 1.0, 'Region-wise ordered Quantity')

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.countplot(x=dataset['Region'], hue=dataset['Category'])
plt.title('Region-wise ordered product categories')
# Out:
# Text(0.5, 1.0, 'Region-wise ordered product categories')

# %% [markdown]
# ### From the above graphe we can see that west region has most orders and south region has least orders

# %% [markdown]
# ## Cateegory-wise analysis of Profit, Sales and Discount

# %%
dataset.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %% [markdown]
# ## Compute top categories in terms of sales and in terms of profit and visualise it with plot

# %%
s = dataset.groupby("Category").Sales.sum()

p = dataset.groupby("Category").Profit.sum()

plt.style.use('seaborn')
s.plot(kind = 'bar', figsize = (10,5), fontsize = 14, color='red')
p.plot(kind = 'bar', figsize = (10,5), fontsize = 14, color='yellow')
plt.xlabel('Category',fontsize = 15)
plt.ylabel('Total Sales/Profits',fontsize = 15)
plt.show()

# %% [markdown]
# ## Sub-Category wise analysis of Profit, Sales and Discount

# %%
dataset.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918
# Labels          34.303055  0.068681   15.236962
# Machines      1645.553313  0.306087   29.432669
# Paper           57.284092  0.074891   24.856620
# Phones         371.211534  0.154556   50.073938
# Storage        264.590553  0.074704   25.152277
# Supplies       245.650200  0.076842   -6.258418
# Tables         648.794771  0.261285  -55.565771

# %% [markdown]
# ## Visualise the distribution of sub-category

# %%
plt.figure(figsize=(18,8))
sns.countplot(df['Sub-Category'])
plt.title('Sub-Category', fontsize=15)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Sub-Category')

# %% [markdown]
# ## Compute top sub-categories in terms of sales and in terms of profit. Visualise the distribution

# %%
sc = dataset.groupby("Sub-Category").Sales.sum()

scp = dataset.groupby("Sub-Category").Profit.sum()

plt.style.use('seaborn')
sc.plot(kind = 'bar', figsize = (10,5),fontsize = 14, color = 'black')
scp.plot(kind = 'bar', figsize = (10,5),fontsize = 14, color = 'y')
plt.xlabel('Sub-Category', fontsize = 15)
plt.ylabel('Total Sales/Profits',fontsize = 15 )
plt.title("Sub-Category Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# ## Get a more detailed view using horizontal bar plot

# %%
plt.figure(figsize=(12,12))
statewise = dataset.groupby(['Sub-Category'])['Profit'].sum()
statewise.plot.barh()
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %% [markdown]
# ## The above bar graph shows us that Copiers and Phones have the highest sales and profit. Tables have most negative profit

# %%
plt.figure(figsize=(10,4))
sns.countplot(df['Discount'])
plt.title('Discount Graph with respect of count (Quantity)', fontsize = 15)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Discount Graph with respect of count (Quantity)')

# %%
fig,axes = plt.subplots(2,2,figsize=(14,12))
fig.suptitle("Distribution plots", fontsize=16)
sns.distplot(df['Sales'], ax=axes[0,0])
sns.distplot(df['Profit'], ax=axes[0,1])
sns.distplot(df['Discount'], ax=axes[1,0])
sns.distplot(df['Quantity'], ax=axes[1,1])
axes[0][0].set_title('Sales Distribution')
axes[0][1].set_title('Profit Distribution')
axes[1][0].set_title('Discount Distribution')
axes[1][1].set_title('Quantity Distribution')
plt.show()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## In the above graph we see that Sales distribution is rightly skewed and Profit distribution is  normal skewed.

# %% [markdown]
# ## State-wise analysis

# %%
new_df=dataset['State'].value_counts()
new_df.head()
# Out:
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: State, dtype: int64

# %%
min=dataset['State'].value_counts().min()
min
# Out:
# 1

# %%
max=dataset['State'].value_counts().max()
max
# Out:
# 2001

# %% [markdown]
# ## State-wise analysis of Profit, Sales and Discount

# %%
dataset.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                             Sales  Discount      Profit
# State
# Alabama                319.846557  0.000000   94.865989
# Arizona                157.508933  0.303571  -15.303235
# Arkansas               194.635500  0.000000   66.811452
# California             228.729451  0.072764   38.171608
# Colorado               176.418231  0.316484  -35.867351
# Connecticut            163.223866  0.007317   42.823071
# Delaware               285.948635  0.006250  103.930988
# District of Columbia   286.502000  0.000000  105.958930
# Florida                233.612815  0.299347   -8.875461
# Georgia                266.825217  0.000000   88.315453
# Idaho                  208.689810  0.085714   39.367767
# Illinois               162.939230  0.390041  -25.625787
# Indiana                359.431946  0.000000  123.375411
# Iowa                   152.658667  0.000000   39.460397
# Kansas                 121.429583  0.000000   34.851813
# Kentucky               263.250000  0.000000   80.573357
# Louisiana              219.453095  0.000000   52.288150
# Maine                  158.816250  0.000000   56.810775
# Maryland               225.766886  0.005714   66.963608
# Massachusetts          212.106919  0.015556   50.262975
# Michigan               299.096525  0.007059   95.934069
# Minnesota              335.541011  0.000000  121.608847
# Mississippi            203.232830  0.000000   59.867475
# Missouri               336.441667  0.000000   97.518341
# Montana                372.623467  0.066667  122.221900
# Nebraska               196.445526  0.000000   53.607742
# Nevada                 428.951333  0.061538   85.045279
# New Hampshire          270.093481  0.011111   63.203807
# New Jersey             275.110092  0.004615   75.176260
# New Mexico             129.284378  0.059459   31.273408
# New York               275.599531  0.055319   65.637011
# North Carolina         223.305880  0.283534  -30.083985
# North Dakota           131.415714  0.000000   32.878529
# Ohio                   166.861697  0.324947  -36.186304
# Oklahoma               298.233182  0.000000   73.544788
# Oregon                 140.573790  0.288710   -9.600569
# Pennsylvania           198.487077  0.328620  -26.507598
# Rhode Island           404.070643  0.021429  130.100523
# South Carolina         201.945476  0.000000   42.120395
# South Dakota           109.630000  0.000000   32.902358
# Tennessee              167.551219  0.291257  -29.189583
# Texas                  172.779742  0.370193  -26.121174
# Utah                   211.699170  0.060377   48.047802
# Vermont                811.760909  0.000000  204.088936
# Virginia               315.342500  0.000000   83.026564
# Washington             273.994605  0.064032   66.013146
# West Virginia          302.456000  0.075000   46.480400
# Wisconsin              291.951000  0.000000   76.380004
# Wyoming               1603.136000  0.200000  100.196000

# %% [markdown]
# ## Plot the state-wise dealings

# %%
new_df.plot(kind='bar',figsize=(12,6))
plt.xlabel('Sates')
plt.ylabel('Number of Deals')
plt.title('State-wise Dealings')
# Out:
# Text(0.5, 1.0, 'State-wise Dealings')

# %% [markdown]
# ## Compute states in term of Sales and in terms of Profit. Plot state's Sales vs Profit

# %%
ss = dataset.groupby("State").Sales.sum()

ps = dataset.groupby("State").Profit.sum()

plt.style.use('seaborn')
ss.plot(kind = 'bar', figsize = (14,6), fontsize = 14, color='g')
ps.plot(kind = 'bar', figsize = (14,6), fontsize = 14, color='k')
plt.xlabel('States',fontsize = 15)
plt.ylabel('Total sales', fontsize = 15)
plt.title("State Sales vs Profit", fontsize = 15)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## Weak Areas
# ### 1) Sales of furnitutre should be limited and that of technology and office supplies should be increased as furniture gives less profit.
# ### 2) Sales should be increased in east as profit is more.
# ### 3) We should give some discounts in some states like Colorado, Texas, Ohio, North Carolina as sales is good but there is no profit

# %% [markdown]
# # Other points :

# %% [markdown]
# ## 1) Less quality products have high sales.
# ## 2) Profit and Discount are related.
# ## 3) The home office provides highest sales followed by Corporate.
# ## 4) We should also focus on higher profit states for more profit.
